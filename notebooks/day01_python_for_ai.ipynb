# %%
import numpy
import pandas
import sklearn
import matplotlib

print("My AI environment is working!")
import sys
print(sys.executable)
import numpy
import pandas
import matplotlib

print("NumPy:", numpy.__version__)
print("Pandas:", pandas.__version__)
print("Matplotlib:", matplotlib.__version__)
print("All packages are working!")
# Out:
# My AI environment is working!
# c:\Users\user\klab-Ai-Rose\.venv\Scripts\python.exe
# NumPy: 2.5.2
# Pandas: 3.0.5
# Matplotlib: 3.11.1
# All packages are working!
